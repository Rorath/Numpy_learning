# %%
from operator import index

import pandas as pd
import numpy as np

# %% [markdown]
# # pd.Series

# %%
a = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'],dtype='float')
print(a)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# dtype: float64

# %%
a = pd.Series({'A': 1, 'B': 2,'C': 3, 'D': 4, 'E': 5},dtype='float', name = 'use dic to create a series')
print(a)
# Out:
# A    True
# B    True
# C    True
# D    True
# E    True
# Name: use dic to create a series, dtype: bool

# %% [markdown]
#  # access to the ___element___

# %%
a = pd.Series({'A': 1, 'B': 2,'C': 3, 'D': 4, 'E': 5},dtype='float', name = 'use dic to create a series')
print(pd.Series(a,index = ['C','L','E']))
# Out:
# C    3.0
# L    NaN
# E    5.0
# Name: use dic to create a series, dtype: float64

# %% [markdown]
# # __PROPERTY__ of series

# %%
a = pd.Series({'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5}, dtype='float', name='use dic to create a series')
print(a.index)
print(a.values)
print(a.shape, a.ndim, a.size)

print(a.loc['B'])
print(a.iloc[1])
print(a.loc['B':'D'])  # the last index is concluded
print(a.iloc[1:3])

print(a.at['B'])
print(a.iat[1])
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')
# [1. 2. 3. 4. 5.]
# (5,) 1 5
# 2.0
# 2.0
# B    2.0
# C    3.0
# D    4.0
# Name: use dic to create a series, dtype: float64
# B    2.0
# C    3.0
# Name: use dic to create a series, dtype: float64
# 2.0
# 2.0

# %% [markdown]
# # s[key] is an appropriate way to access to corresponding value
# # but _s[index]_ is inappropriate

# %%
print(a['A'])
# Out:
# 1.0

# %% [markdown]
# # filtering

# %%
a = pd.Series(np.arange(10), index=map(lambda x: x.upper(), ['a','b','c','d','e','f','g','h','i','j']), name='pretty cool')
print(a)
print(a[a>5])
# Out:
# A    0
# B    1
# C    2
# D    3
# E    4
# F    5
# G    6
# H    7
# I    8
# J    9
# Name: pretty cool, dtype: int64
# G    6
# H    7
# I    8
# J    9
# Name: pretty cool, dtype: int64

# %% [markdown]
# # head and tail

# %%
print(a.head(n=6))# default value for n is 5
print(a.tail())
# Out:
# A    0
# B    1
# C    2
# D    3
# E    4
# dtype: int64
# F    5
# G    6
# H    7
# I    8
# J    9
# dtype: int64

# %%
a.head()
# Out:
# A    0
# B    1
# C    2
# D    3
# E    4
# Name: pretty cool, dtype: int64

# %%
a.describe()
# Out:
# count    10.00000
# mean      4.50000
# std       3.02765
# min       0.00000
# 25%       2.25000
# 50%       4.50000
# 75%       6.75000
# max       9.00000
# Name: pretty cool, dtype: float64

# %% [markdown]
# # number of valid elements Nan will be ignored

# %%
print(a.count())
# Out:
# 10

# %% [markdown]
# # access to keys/index

# %%
print(a.keys())
print(index)
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'], dtype='object')
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'], dtype='object')

# %% [markdown]
# # detect Nan

# %%
a = pd.Series([1,3,np.nan,None,5])
print(a.isna())
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
a = pd.Series(np.arange(10))
print(a.iloc[0], a.loc[1])
# Out:
# 0 1
